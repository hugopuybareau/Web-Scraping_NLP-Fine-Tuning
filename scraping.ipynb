# %%
# Imports 

import requests # HTTP requests 
from bs4 import BeautifulSoup # Extract HTML content

import numpy as np

# %%
# Simple scraper

def scrape_tech_news():

    url = 'https://www.ft.com/technology'

    # HTTP request to scrap page information
    headers = {'User-Agent': 'Mozilla/5.0'}
    response = requests.get(url, headers=headers)

    # Check response status
    if response.status_code != 200:
        print(f"Échec du scraping : {response.status_code}")
        return
    
    # HTML content analysis
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Find all the article listed on the page
    articles = soup.find_all('div', class_='o-teaser__content')
    
    news = []
    
    for article in articles:
        # Title and link extraction
        article_heading = article.find('a', class_='js-teaser-heading-link')
        title = article_heading.get_text(strip=True) if article_heading else "No title"
        link = "https://www.ft.com" + article_heading['href'] if article_heading else "No link"
        
        # Extract article tag to define categories
        article_tag = article.find('a', class_='o-teaser__tag')
        tag = article_tag['aria-label'] if article_tag else 'No cat'
        tag = tag.replace('Category: ', '')
        
        news.append({
            'title': title,
            'link': link,
            'tag': tag,
        })
    
    return news

ft_news_scraped = scrape_tech_news()

# Print
for article in ft_news_scraped:
    print(f"Title: {article['title']}")
    print(f"Link: {article['link']}")
    print(f"Category: {article['tag']}")
    print("-" * 100)
# Out:
# Title: FBI probes whether Silicon Valley venture firm passed secrets to China
# Link: https://www.ft.com/content/d94a5467-ebf9-4992-af13-3e71061707a4
# Category: Industrial espionage
# ----------------------------------------------------------------------------------------------------
# Title: Google files Brussels complaint against Microsoft cloud business
# Link: https://www.ft.com/content/65567a16-434c-4865-9098-2cc8a0c76f68
# Category: EU tech regulation
# ----------------------------------------------------------------------------------------------------
# Title: Uber’s next act: taking on Amazon
# Link: https://www.ft.com/content/7b503c54-ee5b-4413-ad06-580cdab531e5
# Category: The Big Read
# ----------------------------------------------------------------------------------------------------
# Title: US antitrust lawsuit accuses Visa of using dominance to shut down rivals
# Link: https://www.ft.com/content/59479f79-7f0b-43c2-973c-1578e2999c3c
# Category: Visa Inc
# ----------------------------------------------------------------------------------------------------
# Title: Huawei laptop reveals China’s progress towards tech self-sufficiency
# Link: https://www.ft.com/content/5511d73a-1ada-4884-a559-681502300e4f
# Category: Chinese business & finance
# ----------------------------------------------------------------------------------------------------
# Title: US proposes banning Chinese software and components in vehicles
# Link: https://www.ft.com/content/a04ec57d-38ba-4e1f-8e28-d4c76081900b
# Category: US-China trade dispute
# ----------------------------------------------------------------------------------------------------
# Title: Move over copilots: meet the next generation of AI-powered assistants
# Link: https://www.ft.com/content/372536b1-08dd-4161-b6e3-4d09ba235ae8
# Category: Artificial intelligence
# ----------------------------------------------------------------------------------------------------
# Title: With Bluesky, the social media echo chamber is back in vogue
# Link: https://www.ft.com/content/65961fec-a5ab-4c71-b1c8-265be3583a93
# Category: Jemima Kelly
# ----------------------------------------------------------------------------------------------------
# Title: War in the age of AI demands new weaponry
# Link: https://www.ft.com/content/fe136479-9504-4588-869f-900f2b3452c4
# Category: Eric Schmidt
# ----------------------------------------------------------------------------------------------------
# Title: Intel’s long-shot turnaround hits a critical stage
# Link: https://www.ft.com/content/12296719-f7ab-4134-a7e8-bb46e9dc962e
# Category: Richard Waters
# ----------------------------------------------------------------------------------------------------
# Title: Why Foxconn’s next bid for growth is a room on wheels
# Link: https://www.ft.com/content/bb6652eb-c05e-40cf-869f-87797b0a8c2a
# Category: Foxconn Technology Group
# ----------------------------------------------------------------------------------------------------
# Title: The mystery of Masayoshi Son, SoftBank’s great disrupter
# Link: https://www.ft.com/content/424eb5f8-efb4-4fc8-b86a-0359f6fac9eb
# Category: The Weekend Essay
# ----------------------------------------------------------------------------------------------------
# Title: Telegram: a crypto firm with a sideline in messaging
# Link: https://www.ft.com/content/242552a9-4280-46c0-9d61-bcf6ccd14400
# Category: Telegram
# ----------------------------------------------------------------------------------------------------
# Title: The trouble with deepfakes: a new FT podcast series
# Link: https://www.ft.com/content/646ab305-3408-47ca-a59b-57fc73b9ade3
# Category: Artificial intelligence
# ----------------------------------------------------------------------------------------------------
# Title: Who’s afraid of Elon Musk?
# Link: https://www.ft.com/content/b2910e6f-d390-40ad-a896-e8ba9f9f9249
# Category: The Big Read
# ----------------------------------------------------------------------------------------------------
# Title: Big Tech’s bid to rewrite the rules on net zero
# Link: https://www.ft.com/content/2d6fc319-2165-42fb-8de1-0edf1d765be3
# Category: Climate Capital
# ----------------------------------------------------------------------------------------------------
# Title: Can anyone stop Google’s illegal monopoly?
# Link: https://www.ft.com/content/8a1a7090-cb8b-444f-a402-66a1582600ac
# Category: Google LLC
# ----------------------------------------------------------------------------------------------------
# Title: FBI probes whether Silicon Valley venture firm passed secrets to China
# Link: https://www.ft.com/content/d94a5467-ebf9-4992-af13-3e71061707a4
# Category: No cat
# ----------------------------------------------------------------------------------------------------
# Title: Uber’s next act: taking on Amazon
# Link: https://www.ft.com/content/7b503c54-ee5b-4413-ad06-580cdab531e5
# Category: No cat
# ----------------------------------------------------------------------------------------------------
# Title: US antitrust lawsuit accuses Visa of using dominance to shut down rivals
# Link: https://www.ft.com/content/59479f79-7f0b-43c2-973c-1578e2999c3c
# Category: No cat
# ----------------------------------------------------------------------------------------------------
# Title: ‘Mobile phone on wheels’: Toyota and VW fall further behind in the software race
# Link: https://www.ft.com/content/7e5677b8-87fa-41fa-8648-9009ac7f14fc
# Category: No cat
# ----------------------------------------------------------------------------------------------------
# Title: Raspberry Pi boosted by higher than expected profits
# Link: https://www.ft.com/content/3cfc7f90-2885-4a9c-bca5-2a2d23d21735
# Category: No cat
# ----------------------------------------------------------------------------------------------------
# Title: Did this VC obtain trade secrets for China?
# Link: https://www.ft.com/content/21d59507-a60b-43e8-82bf-14a9d570678f
# Category: Due Diligence
# ----------------------------------------------------------------------------------------------------
# Title: Bari Weiss’s media start-up valued at $100mn in funding round
# Link: https://www.ft.com/content/de999cfe-1604-41e4-9ba4-c2ad42cefb9c
# Category: Media
# ----------------------------------------------------------------------------------------------------
# Title: Energy-hungry tech groups express interest in US-led carbon credits scheme
# Link: https://www.ft.com/content/03ecd17c-ccd3-4ba7-9619-9fcd7f00332f
# Category: Climate change
# ----------------------------------------------------------------------------------------------------
# Title: Qatar’s Ooredoo wades into Gulf’s AI data centre rivalry
# Link: https://www.ft.com/content/4d5b4a60-c492-4cab-aba4-1063036c3e29
# Category: Artificial intelligence
# ----------------------------------------------------------------------------------------------------
# Title: Raspberry Pi boosted by higher than expected profits
# Link: https://www.ft.com/content/3cfc7f90-2885-4a9c-bca5-2a2d23d21735
# Category: Raspberry Pi
# ----------------------------------------------------------------------------------------------------
# Title: UAE president meets Joe Biden in push for more US AI technology
# Link: https://www.ft.com/content/e85bef92-5f53-4f71-bb3b-a0d65f3a4c48
# Category: United Arab Emirates
# ----------------------------------------------------------------------------------------------------
# Title: Lobbying for unfettered innovation is bad for democracy
# Link: https://www.ft.com/content/ab2761bd-ace7-428b-aa3e-b7412ef69b48
# Category: Marietje Schaake
# ----------------------------------------------------------------------------------------------------
# Title: One way or another, Intel is for sale
# Link: https://www.ft.com/content/64353567-4465-49ea-b614-cf4a62288d06
# Category: Technology sector
# ----------------------------------------------------------------------------------------------------
# Title: UFO 50 — ingenious compendium of 1980s arcade games that never existed
# Link: https://www.ft.com/content/b9794b97-b48d-491c-a1f1-91a3b25f073f
# Category: Gaming
# ----------------------------------------------------------------------------------------------------
# Title: EQT plans to sell stake in €15bn software group IFS
# Link: https://www.ft.com/content/5ea5b289-4bfe-4332-877c-d6be47dbf35a
# Category: EQT Partners AB
# ----------------------------------------------------------------------------------------------------
# Title: Eutelsat explores partnerships to fund Europe’s space-based network
# Link: https://www.ft.com/content/f61e2375-3d66-426a-8549-d4cadebb8156
# Category: Eutelsat SA
# ----------------------------------------------------------------------------------------------------
# Title: ‘Mobile phone on wheels’: Toyota and VW fall further behind in the software race
# Link: https://www.ft.com/content/7e5677b8-87fa-41fa-8648-9009ac7f14fc
# Category: Electric vehicles
# ----------------------------------------------------------------------------------------------------
# Title: Qualcomm has approached Intel about takeover bid
# Link: https://www.ft.com/content/c434aa54-d3ef-45d3-a7f4-1d45f43133fc
# Category: Qualcomm Inc
# ----------------------------------------------------------------------------------------------------
# Title: Perplexity in talks with top brands on ads model as it challenges Google
# Link: https://www.ft.com/content/ecf299f4-e0a9-468b-af06-8a94e5f0b1f4
# Category: Perplexity
# ----------------------------------------------------------------------------------------------------
# Title: The mystery of Masayoshi Son, SoftBank’s great disrupter
# Link: https://www.ft.com/content/424eb5f8-efb4-4fc8-b86a-0359f6fac9eb
# Category: The Weekend Essay
# ----------------------------------------------------------------------------------------------------
# Title: Microsoft in deal for Three Mile Island nuclear power to meet AI demand
# Link: https://www.ft.com/content/ddcb5ab6-965f-4034-96e1-7f668bad1801
# Category: Nuclear energy
# ----------------------------------------------------------------------------------------------------
# Title: Investors pile into OpenAI’s $6bn funding round in unprecedented bet
# Link: https://www.ft.com/content/a8f9bd05-0999-415d-af86-c73e79ad5733
# Category: OpenAI
# ----------------------------------------------------------------------------------------------------
# Title: Elon Musk’s Starlink faces legal jeopardy in Brazil after X ban
# Link: https://www.ft.com/content/23f2ebbc-9d6e-49c1-ba77-3f3e557251b3
# Category: Space Exploration Technologies Corp
# ----------------------------------------------------------------------------------------------------
# Title: US and Taiwan seek to strengthen drone supply chain to keep out China
# Link: https://www.ft.com/content/ce851c48-6aa5-48d2-b28a-6c806cc10518
# Category: Aerospace & Defence
# ----------------------------------------------------------------------------------------------------
# Title: Amazon says workers need to be in the office. Most of Silicon Valley disagrees.
# Link: https://www.ft.com/content/c7b82efc-9174-4fc0-8f06-6c6a884d5105
# Category: Flexible working
# ----------------------------------------------------------------------------------------------------
# Title: Business books: what to read this month
# Link: https://www.ft.com/content/9adb8f15-f488-4a48-86d5-983aaef0dba3
# Category: The best books of the week
# ----------------------------------------------------------------------------------------------------
# Title: Axel Springer top team close to making eight times their money in KKR deal
# Link: https://www.ft.com/content/bac4240e-c153-49f0-996a-2aeb0dfe470f
# Category: Axel Springer SE
# ----------------------------------------------------------------------------------------------------
# Title: The dramatic decline of China’s innovative start-ups
# Link: https://www.ft.com/content/00ba7924-4b51-4138-acc4-9667efd5e898
# Category: The editorial board
# ----------------------------------------------------------------------------------------------------
# Title: Brazil imposes fine on Musk’s X after service returns
# Link: https://www.ft.com/content/2133cca8-ff48-4e11-8ca7-bd35d69201c5
# Category: X Corp
# ----------------------------------------------------------------------------------------------------
# Title: AI risks making some people ‘uninsurable’, warns UK watchdog
# Link: https://www.ft.com/content/9f9d3a54-d08b-4d9c-a000-d50460f818dc
# Category: Financial & markets regulation
# ----------------------------------------------------------------------------------------------------

# %%
# Pre-trained model to generate text 

from openai import OpenAI # I won't use openai cause there is a limit for the requests. 
from transformers import T5ForConditionalGeneration, T5Tokenizer # Prompt issue
from transformers import BartForConditionalGeneration, BartTokenizer


client = OpenAI(
    api_key = "xxx"
)

# # T5 model

# model_name = 't5-base'
# tokenizer = T5Tokenizer.from_pretrained(model_name)
# model = T5ForConditionalGeneration.from_pretrained(model_name)

# Bart model
model_name = "facebook/bart-large-cnn" # already trained
tokenizer = BartTokenizer.from_pretrained(model_name)
model = BartForConditionalGeneration.from_pretrained(model_name)
# Out:
# /Users/hugopuybareau/Documents/GitHub/LLM_project/LLM_project_env/lib/python3.9/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
def generate_content_from_title(title):
    prompt = f"Rédige un article d'analyse en français basé sur ce titre : {title}."

    inputs = tokenizer(prompt, return_tensors="pt", max_length=512, truncation=True)

    outputs = model.generate(inputs.input_ids, max_length=500, num_beams=4, early_stopping=True)

    # Décoder le texte généré
    article = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return article

for article in ft_news_scraped:
    title = article['title']
    # tag = article['tag']
    article['content'] = generate_content_from_title(title)

# Print
for article in ft_news_scraped:
    print(f"Title: {article['title']}")
    print(f"Link: {article['link']}")
    print(f"Category: {article['tag']}")
    print(f"Content: {article['content']}")
    print("-" * 40)
# Out:
# Title: FBI probes whether Silicon Valley venture firm passed secrets to China
# Link: https://www.ft.com/content/d94a5467-ebf9-4992-af13-3e71061707a4
# Category: Industrial espionage
# Content: Rédige un article d'analyse en français basé sur ce titre. FBI probes whether Silicon Valley venture firm passed secrets to China. FBI: Silicon Valley firm passed secret to China, according to reports. C'est la première version d'un article dans laquelle l'on analyse.
# ----------------------------------------
# Title: Google files Brussels complaint against Microsoft cloud business
# Link: https://www.ft.com/content/65567a16-434c-4865-9098-2cc8a0c76f68
# Category: EU tech regulation
# Content: Rédige un article d'analyse en français basé sur ce titre : Google files Brussels complaint against Microsoft cloud business. Google files complaints against Microsoft over cloud business in Brussels. Google says it has no plans to pull out of the cloud market.
# ----------------------------------------
# Title: Uber’s next act: taking on Amazon
# Link: https://www.ft.com/content/7b503c54-ee5b-4413-ad06-580cdab531e5
# Category: The Big Read
# Content: Rédige un article d'analyse en français basé sur ce titre : Uber’s next act: taking on Amazon. Uber is a ride-hailing service based in San Francisco, California. The company has raised more than $1 billion in its first three months.
# ----------------------------------------
# Title: US antitrust lawsuit accuses Visa of using dominance to shut down rivals
# Link: https://www.ft.com/content/59479f79-7f0b-43c2-973c-1578e2999c3c
# Category: Visa Inc
# Content: Rédige un article d'analyse en français basé sur ce titre. US antitrust lawsuit accuses Visa of using dominance to shut down rivals. Visa is accused of using its dominance to stop rivals from entering the market. Visa denies the allegations and says it is not breaking any laws.
# ----------------------------------------
# Title: Huawei laptop reveals China’s progress towards tech self-sufficiency
# Link: https://www.ft.com/content/5511d73a-1ada-4884-a559-681502300e4f
# Category: Chinese business & finance
# Content: Rédige un article d'analyse en français basé sur ce titre : Huawei laptop reveals China’s progress towards tech self-sufficiency. Rédigite un article  basé on cette titre.
# ----------------------------------------
# Title: US proposes banning Chinese software and components in vehicles
# Link: https://www.ft.com/content/a04ec57d-38ba-4e1f-8e28-d4c76081900b
# Category: US-China trade dispute
# Content: Rédige un article d'analyse en français basé sur ce titre : US proposes banning Chinese software and components in vehicles. U.S. proposes ban on Chinese software, components in cars. US wants to stop use of Chinese-made software, parts in cars and trucks.
# ----------------------------------------
# Title: Move over copilots: meet the next generation of AI-powered assistants
# Link: https://www.ft.com/content/372536b1-08dd-4161-b6e3-4d09ba235ae8
# Category: Artificial intelligence
# Content: Rédige un article d'analyse en français basé sur ce titre. Move over copilots: meet the next generation of AI-powered assistants. The future of personal assistants will be powered by artificial intelligence, say tech experts.
# ----------------------------------------
# Title: With Bluesky, the social media echo chamber is back in vogue
# Link: https://www.ft.com/content/65961fec-a5ab-4c71-b1c8-265be3583a93
# Category: Jemima Kelly
# Content: Rédige un article d'analyse en français basé sur ce titre : With Bluesky, the social media echo chamber is back in vogue. Rédigite un article  basé on cette titre: With Blueski, theSocial Media Echo Chamber is Back.
# ----------------------------------------
# Title: War in the age of AI demands new weaponry
# Link: https://www.ft.com/content/fe136479-9504-4588-869f-900f2b3452c4
# Category: Eric Schmidt
# Content: Rédige un article d'analyse en français basé sur ce titre : War in the age of AI demands new weaponry. Rédique un article  basé on ce title : War In the age Of AI demands New Weapons.
# ----------------------------------------
# Title: Intel’s long-shot turnaround hits a critical stage
# Link: https://www.ft.com/content/12296719-f7ab-4134-a7e8-bb46e9dc962e
# Category: Richard Waters
# Content: Rédige un article d'analyse en français basé sur ce titre : Intel’s long-shot turnaround hits a critical stage. Intel: “We are confident in our ability to continue to make progress.’’
# ----------------------------------------
# Title: Why Foxconn’s next bid for growth is a room on wheels
# Link: https://www.ft.com/content/bb6652eb-c05e-40cf-869f-87797b0a8c2a
# Category: Foxconn Technology Group
# Content: Rédige un article d'analyse en français basé sur ce titre. Why Foxconn’s next bid for growth is a room on wheels. Foxconn: ‘I’m not worried. I’ve got a lot of experience.’
# ----------------------------------------
# Title: The mystery of Masayoshi Son, SoftBank’s great disrupter
# Link: https://www.ft.com/content/424eb5f8-efb4-4fc8-b86a-0359f6fac9eb
# Category: The Weekend Essay
# Content: Rédige un article d'analyse en français basé sur ce titre : The mystery of Masayoshi Son, SoftBank’s great disrupter. Rédigite un article  basé on cette titre.
# ----------------------------------------
# Title: Telegram: a crypto firm with a sideline in messaging
# Link: https://www.ft.com/content/242552a9-4280-46c0-9d61-bcf6ccd14400
# Category: Telegram
# Content: Rédige un article d'analyse en français basé sur ce titre : Telegram: a crypto firm with a sideline in messaging. Telegram is an app that lets users send messages to each other via the Telegram app. The app was launched in 2012 and is now used by more than 100 million people.
# ----------------------------------------
# Title: The trouble with deepfakes: a new FT podcast series
# Link: https://www.ft.com/content/646ab305-3408-47ca-a59b-57fc73b9ade3
# Category: Artificial intelligence
# Content: Rédige un article d'analyse en français basé sur ce titre. The trouble with deepfakes: a new FT podcast series. Click here to listen to the first episode of The Trouble with Deepfakes, a new podcast series by the FT.
# ----------------------------------------
# Title: Who’s afraid of Elon Musk?
# Link: https://www.ft.com/content/b2910e6f-d390-40ad-a896-e8ba9f9f9249
# Category: The Big Read
# Content: Rédige un article d'analyse en français basé sur ce titre : Who’s afraid of Elon Musk?. Rédigite un article  basé on cette titre: Who's afraid of Musk?
# ----------------------------------------
# Title: Big Tech’s bid to rewrite the rules on net zero
# Link: https://www.ft.com/content/2d6fc319-2165-42fb-8de1-0edf1d765be3
# Category: Climate Capital
# Content: Rédige un article d'analyse en français basé sur ce titre : Big Tech’s bid to rewrite the rules on net zero. Big Tech wants to rewrite rules on Net zero, says it will make it easier for companies to make money.
# ----------------------------------------
# Title: Can anyone stop Google’s illegal monopoly?
# Link: https://www.ft.com/content/8a1a7090-cb8b-444f-a402-66a1582600ac
# Category: Google LLC
# Content: Rédige un article d'analyse en français basé sur ce titre : Can anyone stop Google’s illegal monopoly?. Rédigite un article  basé on cette titre: CanAnyone stop Google's illegal monopoly?.
# ----------------------------------------
# Title: FBI probes whether Silicon Valley venture firm passed secrets to China
# Link: https://www.ft.com/content/d94a5467-ebf9-4992-af13-3e71061707a4
# Category: No cat
# Content: Rédige un article d'analyse en français basé sur ce titre. FBI probes whether Silicon Valley venture firm passed secrets to China. FBI: Silicon Valley firm passed secret to China, according to reports. C'est la première version d'un article dans laquelle l'on analyse.
# ----------------------------------------
# Title: Uber’s next act: taking on Amazon
# Link: https://www.ft.com/content/7b503c54-ee5b-4413-ad06-580cdab531e5
# Category: No cat
# Content: Rédige un article d'analyse en français basé sur ce titre : Uber’s next act: taking on Amazon. Uber is a ride-hailing service based in San Francisco, California. The company has raised more than $1 billion in its first three months.
# ----------------------------------------
# Title: US antitrust lawsuit accuses Visa of using dominance to shut down rivals
# Link: https://www.ft.com/content/59479f79-7f0b-43c2-973c-1578e2999c3c
# Category: No cat
# Content: Rédige un article d'analyse en français basé sur ce titre. US antitrust lawsuit accuses Visa of using dominance to shut down rivals. Visa is accused of using its dominance to stop rivals from entering the market. Visa denies the allegations and says it is not breaking any laws.
# ----------------------------------------
# Title: ‘Mobile phone on wheels’: Toyota and VW fall further behind in the software race
# Link: https://www.ft.com/content/7e5677b8-87fa-41fa-8648-9009ac7f14fc
# Category: No cat
# Content: Rédige un article d'analyse en français basé sur ce titre : ‘Mobile phone on wheels’: Toyota and VW fall further behind in the software race. Toyota: ‘We have no plans to change the way our cars work.’ VW: “We are committed to making sure our cars are as safe as possible.”
# ----------------------------------------
# Title: Raspberry Pi boosted by higher than expected profits
# Link: https://www.ft.com/content/3cfc7f90-2885-4a9c-bca5-2a2d23d21735
# Category: No cat
# Content: Rédige un article d'analyse en français basé sur ce titre : Raspberry Pi boosted by higher than expected profits. Raspbian Pi is a small computer that can be used to connect to the internet. The Raspberry Pi can also be used as a computer to connect with other computers.
# ----------------------------------------
# Title: Did this VC obtain trade secrets for China?
# Link: https://www.ft.com/content/21d59507-a60b-43e8-82bf-14a9d570678f
# Category: Due Diligence
# Content: Rédige un article d'analyse en français basé sur ce titre : Did this VC obtain trade secrets for China?. Rédigite un article  basé on cette titre: Did thisVC obtain trade secret for China?"
# ----------------------------------------
# Title: Bari Weiss’s media start-up valued at $100mn in funding round
# Link: https://www.ft.com/content/de999cfe-1604-41e4-9ba4-c2ad42cefb9c
# Category: Media
# Content: Rédige un article d'analyse en français basé sur ce titre : Bari Weiss’s media start-up valued at $100mn in funding round. BariWeiss.com is a social media company based in New York.
# ----------------------------------------
# Title: Energy-hungry tech groups express interest in US-led carbon credits scheme
# Link: https://www.ft.com/content/03ecd17c-ccd3-4ba7-9619-9fcd7f00332f
# Category: Climate change
# Content: Rédige un article d'analyse en français basé sur ce titre : Energy-hungry tech groups express interest in US-led carbon credits scheme. Rédigite un article  basé on cette titre.
# ----------------------------------------
# Title: Qatar’s Ooredoo wades into Gulf’s AI data centre rivalry
# Link: https://www.ft.com/content/4d5b4a60-c492-4cab-aba4-1063036c3e29
# Category: Artificial intelligence
# Content: Rédige un article d'analyse en français basé sur ce titre. Qatar’s Ooredoo wades into Gulf’S AI data centre rivalry. Qatar, Saudi Arabia, UAE, UAE and Bahrain all have data centres in the region.
# ----------------------------------------
# Title: Raspberry Pi boosted by higher than expected profits
# Link: https://www.ft.com/content/3cfc7f90-2885-4a9c-bca5-2a2d23d21735
# Category: Raspberry Pi
# Content: Rédige un article d'analyse en français basé sur ce titre : Raspberry Pi boosted by higher than expected profits. Raspbian Pi is a small computer that can be used to connect to the internet. The Raspberry Pi can also be used as a computer to connect with other computers.
# ----------------------------------------
# Title: UAE president meets Joe Biden in push for more US AI technology
# Link: https://www.ft.com/content/e85bef92-5f53-4f71-bb3b-a0d65f3a4c48
# Category: United Arab Emirates
# Content: Rédige un article d'analyse en français basé sur ce titre : UAE president meets Joe Biden in push for more US AI technology. U.S. President Joe Biden met with the president of the United Arab Emirates in Abu Dhabi.
# ----------------------------------------
# Title: Lobbying for unfettered innovation is bad for democracy
# Link: https://www.ft.com/content/ab2761bd-ace7-428b-aa3e-b7412ef69b48
# Category: Marietje Schaake
# Content: Rédige un article d'analyse en français basé sur ce titre : Lobbying for unfettered innovation is bad for democracy. L'article est partie de l'expertise de Jean-Claude Junker, editor-in-chief of Le Monde.
# ----------------------------------------
# Title: One way or another, Intel is for sale
# Link: https://www.ft.com/content/64353567-4465-49ea-b614-cf4a62288d06
# Category: Technology sector
# Content: Rédige un article d'analyse en français basé sur ce titre : One way or another, Intel is for sale. Rédigite un article  basé on cette titre: One way Or Another, Intel Is For Sale.
# ----------------------------------------
# Title: UFO 50 — ingenious compendium of 1980s arcade games that never existed
# Link: https://www.ft.com/content/b9794b97-b48d-491c-a1f1-91a3b25f073f
# Category: Gaming
# Content: Rédige un article d'analyse en français basé sur ce titre : UFO 50. UFO 50 is a compendium of 1980s arcade games that never existed. It is a collection of arcade games from the 1980s that were never released.
# ----------------------------------------
# Title: EQT plans to sell stake in €15bn software group IFS
# Link: https://www.ft.com/content/5ea5b289-4bfe-4332-877c-d6be47dbf35a
# Category: EQT Partners AB
# Content: Rédige un article d'analyse en français basé sur ce titre. EQT plans to sell stake in €15bn software group IFS. IFS is one of the biggest software companies in the world, worth more than $20bn.
# ----------------------------------------
# Title: Eutelsat explores partnerships to fund Europe’s space-based network
# Link: https://www.ft.com/content/f61e2375-3d66-426a-8549-d4cadebb8156
# Category: Eutelsat SA
# Content: Rédige un article d'analyse en français basé sur ce titre : Eutelsat explores partnerships to fund Europe’s space-based network. EUTelsat is a European satellite operator based in Paris, France.
# ----------------------------------------
# Title: ‘Mobile phone on wheels’: Toyota and VW fall further behind in the software race
# Link: https://www.ft.com/content/7e5677b8-87fa-41fa-8648-9009ac7f14fc
# Category: Electric vehicles
# Content: Rédige un article d'analyse en français basé sur ce titre : ‘Mobile phone on wheels’: Toyota and VW fall further behind in the software race. Toyota: ‘We have no plans to change the way our cars work.’ VW: “We are committed to making sure our cars are as safe as possible.”
# ----------------------------------------
# Title: Qualcomm has approached Intel about takeover bid
# Link: https://www.ft.com/content/c434aa54-d3ef-45d3-a7f4-1d45f43133fc
# Category: Qualcomm Inc
# Content: Rédige un article d'analyse en français basé sur ce titre : Qualcomm has approached Intel about takeover bid. Qualcomm has approach Intel about merger, according to reports in the U.S. and Europe. Qualcomm and Intel have not commented on the reports.
# ----------------------------------------
# Title: Perplexity in talks with top brands on ads model as it challenges Google
# Link: https://www.ft.com/content/ecf299f4-e0a9-468b-af06-8a94e5f0b1f4
# Category: Perplexity
# Content: Rédige un article d'analyse en français basé sur ce titre : Perplexity in talks with top brands on ads model as it challenges Google. Rédigite un article  basé on cette titre.
# ----------------------------------------
# Title: The mystery of Masayoshi Son, SoftBank’s great disrupter
# Link: https://www.ft.com/content/424eb5f8-efb4-4fc8-b86a-0359f6fac9eb
# Category: The Weekend Essay
# Content: Rédige un article d'analyse en français basé sur ce titre : The mystery of Masayoshi Son, SoftBank’s great disrupter. Rédigite un article  basé on cette titre.
# ----------------------------------------
# Title: Microsoft in deal for Three Mile Island nuclear power to meet AI demand
# Link: https://www.ft.com/content/ddcb5ab6-965f-4034-96e1-7f668bad1801
# Category: Nuclear energy
# Content: Rédige un article d'analyse en français basé sur ce titre. Microsoft in deal for Three Mile Island nuclear power to meet AI demand. Microsoft will use the plant to power its cloud-based software. The deal is expected to be completed by the end of the year.
# ----------------------------------------
# Title: Investors pile into OpenAI’s $6bn funding round in unprecedented bet
# Link: https://www.ft.com/content/a8f9bd05-0999-415d-af86-c73e79ad5733
# Category: OpenAI
# Content: Rédige un article d'analyse en français basé sur ce titre. Investors pile into OpenAI’s $6bn funding round in unprecedented bet. OpenAI is an AI company based in San Francisco, California. The company has raised $6 billion in funding so far.
# ----------------------------------------
# Title: Elon Musk’s Starlink faces legal jeopardy in Brazil after X ban
# Link: https://www.ft.com/content/23f2ebbc-9d6e-49c1-ba77-3f3e557251b3
# Category: Space Exploration Technologies Corp
# Content: Rédige un article d'analyse en français basé sur ce titre : Elon Musk’s Starlink faces legal jeopardy in Brazil after X ban. Elon Musk's Starlink could be in trouble in Brazil, according to reports.
# ----------------------------------------
# Title: US and Taiwan seek to strengthen drone supply chain to keep out China
# Link: https://www.ft.com/content/ce851c48-6aa5-48d2-b28a-6c806cc10518
# Category: Aerospace & Defence
# Content: Rédige un article d'analyse en français basé sur ce titre : US and Taiwan seek to strengthen drone supply chain to keep out China. U.S. and Taiwan want to strengthen Drone Supply Chain to Keep out China, says report.
# ----------------------------------------
# Title: Amazon says workers need to be in the office. Most of Silicon Valley disagrees.
# Link: https://www.ft.com/content/c7b82efc-9174-4fc0-8f06-6c6a884d5105
# Category: Flexible working
# Content: Rédige un article d'analyse en français basé sur ce titre : Amazon says workers need to be in the office. Most of Silicon Valley disagrees. Amazon is one of the biggest employers in the U.S. and is based in California.
# ----------------------------------------
# Title: Business books: what to read this month
# Link: https://www.ft.com/content/9adb8f15-f488-4a48-86d5-983aaef0dba3
# Category: The best books of the week
# Content: Rédige un article d'analyse en français basé sur ce titre : Business books: what to read this month. Rédigite un article  basé on ce title : Business Books: What to Read this Month.
# ----------------------------------------
# Title: Axel Springer top team close to making eight times their money in KKR deal
# Link: https://www.ft.com/content/bac4240e-c153-49f0-996a-2aeb0dfe470f
# Category: Axel Springer SE
# Content: Rédige un article d'analyse en français basé sur ce titre : Axel Springer top team close to making eight times their money in KKR deal. Rédigite un article  basé on cette titre.
# ----------------------------------------
# Title: The dramatic decline of China’s innovative start-ups
# Link: https://www.ft.com/content/00ba7924-4b51-4138-acc4-9667efd5e898
# Category: The editorial board
# Content: Rédige un article d'analyse en français basé sur ce titre. The dramatic decline of China’s innovative start-ups. The decline of Chinese start-up companies. The rise and fall of China's start- ups. The fall and rise of Chinese startups.
# ----------------------------------------
# Title: Brazil imposes fine on Musk’s X after service returns
# Link: https://www.ft.com/content/2133cca8-ff48-4e11-8ca7-bd35d69201c5
# Category: X Corp
# Content: Rédige un article d'analyse en français basé sur ce titre : Brazil imposes fine on Musk’s X after service returns. Brazil imposes fines on Musk's X afterService returns. Musk: ‘I’m not breaking any rules. I’ve never broken any laws.’
# ----------------------------------------
# Title: AI risks making some people ‘uninsurable’, warns UK watchdog
# Link: https://www.ft.com/content/9f9d3a54-d08b-4d9c-a000-d50460f818dc
# Category: Financial & markets regulation
# Content: Rédige un article d'analyse en français basé sur ce titre : AI risks making some people ‘uninsurable’, warns UK watchdog. UK watchdog warns some people could be left 'uninsurable' because of AI.
# ----------------------------------------
